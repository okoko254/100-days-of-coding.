# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
df=pd.read_csv("survey_results_public.csv")

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1                     I am a developer by profession      Yes
# 1               2                     I am a developer by profession       No
# 2               3                        I code primarily as a hobby      Yes
# 3               4                     I am a developer by profession      Yes
# 4               5  I used to be a developer by profession, but no...      Yes
# ...           ...                                                ...      ...
# 64456       64858                                                NaN      Yes
# 64457       64867                                                NaN      Yes
# 64458       64898                                                NaN      Yes
# 64459       64925                                                NaN      Yes
# 64460       65112                                                NaN      Yes
#
# ...

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.isnull()
# Out:
#        Respondent  MainBranch  Hobbyist    Age  Age1stCode  CompFreq  \
# 0           False       False     False   True       False     False
# 1           False       False     False   True       False      True
# 2           False       False     False   True       False      True
# 3           False       False     False  False       False      True
# 4           False       False     False  False       False      True
# ...           ...         ...       ...    ...         ...       ...
# 64456       False        True     False   True       False      True
# 64457       False        True     False   True        True      True
# 64458       False        True     False   True        True      True
# 64459       False        True     False   True        True      True
# 64460       False        True     False   True        True      True
#
#        CompTotal  ConvertedComp  Country  CurrencyDesc  ...  SurveyEase  \
# ...

# %%
df.dropna(axis=0,inplace=True)#drops all rows with null values and axis=0 means rows
df
# Out:
#        Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 9              10  I am a developer by profession      Yes  22.0         14
# 32             33  I am a developer by profession      Yes  39.0         14
# 41             42  I am a developer by profession       No  32.0         14
# 46             47  I am a developer by profession      Yes  53.0         10
# 68             69  I am a developer by profession      Yes  25.0         12
# ...           ...                             ...      ...   ...        ...
# 61613       62863  I am a developer by profession      Yes  30.0         11
# 61636       62886  I am a developer by profession      Yes  32.0         24
# 61654       62904  I am a developer by profession      Yes  33.0         24
# 61993       63288  I am a developer by profession       No  31.0         16
# 63517       64938  I am a developer by profession       No  33.0         13
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4213 entries, 9 to 63517
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    4213 non-null   int64
#  1   MainBranch                    4213 non-null   object
#  2   Hobbyist                      4213 non-null   object
#  3   Age                           4213 non-null   float64
#  4   Age1stCode                    4213 non-null   object
#  5   CompFreq                      4213 non-null   object
#  6   CompTotal                     4213 non-null   float64
#  7   ConvertedComp                 4213 non-null   float64
#  8   Country                       4213 non-null   object
#  9   CurrencyDesc                  4213 non-null   object
#  10  CurrencySymbol                4213 non-null   object
#  11  DatabaseDesireNextYear        4213 non-null   object
# ...

# %%
#df['YearsCode']=df['YearsCode'].astype(float) is for converting an object to a float

# %%
df.describe()
#count-number of observations
#mean-average value
#std-how spread out the observations are(low std means most numbers are close to the mean and high std means values are spread out over a wide range)
#min-lowest walue
#max-highest value
#25%,50%,75% are percentiles
# Out:
#          Respondent          Age     CompTotal  ConvertedComp  WorkWeekHrs
# count   4213.000000  4213.000000  4.213000e+03   4.213000e+03  4213.000000
# mean   27533.329694    32.072158  2.740265e+06   1.116038e+05    41.265523
# std    18439.176546     7.482935  4.297804e+07   2.459682e+05    15.344240
# min       10.000000    17.000000  0.000000e+00   0.000000e+00     2.000000
# 25%    12200.000000    26.000000  3.000000e+04   3.037200e+04    40.000000
# 50%    24863.000000    31.000000  7.200000e+04   6.050500e+04    40.000000
# 75%    46016.000000    36.000000  1.300000e+05   1.000000e+05    45.000000
# max    64938.000000    70.000000  1.900000e+09   2.000000e+06   425.000000

# %%
#df.plot(x='WorkWeekHrs',y='Age',kind='line')
#plt.ylim(ymin=0)#value we want the axis to start on
#plt.xlim(xmin=0)
#plt.show()#shows the output
